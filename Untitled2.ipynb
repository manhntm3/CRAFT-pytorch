# %%
import os
import json
occupation_dict = {}
ff = open('occupations_dict.txt','a+')
with open('titles_minor_group_ons.json','r') as f:
    occupation_dict = json.load(f)
for occupations in occupation_dict:
    for occupation in occupation_dict[occupations]:
        if len(occupation.split()) < 5:
            print(occupation)
            ff.write(occupation+"\n")
ff.close()
# Out:
# conservation and environment professionals
# conservation professionals
# environment professionals
# conservation adviser
# countryside adviser
# environmental chemist
# marine conservationist
# coastal nature conservationist
# conservationist
# ecological consultant
# environmental consultant
# ecologist
# environmental engineer
# geoenvironmental engineer
# contaminated land engineer
# landfill engineer
# engineer professional environmental
# environmentalist
# historic buildings inspector
# inspector historic buildings
# heritage interpreter conservation
# conservation manager
# countryside manager
# energy manager
# environmental manager
# heritage manager
# national park manager
# flood risk manager
# flood warning manager
# manager environment agency
# manager environmental consultancy
# countryside access officer
# carbon and sustainability officer
# conservancy officer
# assistant conservation officer government
# chief conservation officer government
# ...

# %%
# !wget https://raw.githubusercontent.com/dariusk/corpora/master/data/humans/occupations.json
# Out:
# --2019-10-01 09:07:40--  https://raw.githubusercontent.com/dariusk/corpora/master/data/humans/occupations.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.8.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.8.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22704 (22K) [text/plain]
# Saving to: ‘occupations.json’
#
# occupations.json    100%[===================>]  22,17K  --.-KB/s    in 0,05s
#
# 2019-10-01 09:07:40 (490 KB/s) - ‘occupations.json’ saved [22704/22704]

# %%
import json
ff = open('occupations_dict.txt','a+')
with open('occupations.json','r') as f:
    occupation_dict = json.load(f)
for occupation in occupation_dict["occupations"]:
    ff.write(occupation+"\n")
ff.close()
